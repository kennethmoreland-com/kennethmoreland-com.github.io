# %% [markdown]
# This was written with Toyplot 0.13. It definitely won't work with older versions.

# %%
import numpy
import pandas
import toyplot.pdf

print toyplot.__version__
# Out:
# 0.13.0

# %% [markdown]
# Read in the data from a csv file.

# %%
data = pandas.read_csv('All_Compositing_SpeedUp.csv')
#data

# %% [markdown]
# Construct the plot for the "Cinema" camera.

# %%
subset_data = data[data.Camera == 'inverse']
subset_data = subset_data[subset_data.Strategy >= 3]
plot_data = subset_data.pivot_table(index=['Workload','Format','Strategy'],
                                    columns='Images',
                                    values='Speedup')
plot_data.reset_index(inplace=True)
plot_data
# Out:
# Images Workload Format  Strategy         20         40         60         80  \
# 0           bal      E         3   4.429180   4.885418   4.405545   4.539387
# 1           bal      E         4   9.661032   9.578474   8.553214   8.393490
# 2           bal      S         3   1.892004   2.282544   2.513664   2.933944
# 3           bal      S         4   6.089707   5.121941   4.735191   4.750330
# 4           imb      E         3   4.408279   5.324808   4.992480   5.204870
# 5           imb      E         4  16.711930  18.970486  19.337076  18.066623
# 6           imb      S         3   1.499561   1.772231   2.419403   2.587637
# 7           imb      S         4   5.481320   6.101561   6.321707   6.130891
# 8           iso      E         3   3.333430   3.978468   4.380927   4.649950
# 9           iso      E         4  13.924698  14.891250  13.398796  14.059942
# 10          iso      S         3   1.389251   1.566148   1.833714   1.692833
# 11          iso      S         4   5.347850   4.940055   5.197028   4.495581
# 12          slc      E         3   3.805310   5.553651   4.746872   4.998143
# 13          slc      E         4  16.623563  20.356316  22.033734  21.659090
# 14          slc      S         3   1.382271   1.462856   1.855826   1.922853
# 15          slc      S         4   5.712659   5.426244   5.088338   4.952841
#
# Images        100
# 0        4.450754
# 1        7.612073
# 2        2.932558
# 3        4.490810
# 4        5.410282
# 5       19.630067
# 6        2.662647
# 7        5.906745
# 8        4.885928
# 9       13.333687
# 10       1.982354
# 11       4.371103
# 12       5.316813
# 13      22.218501
# 14       2.263330
# 15       4.772914

# %% [markdown]
# Change order of entries.

# %%
plot_data.Format = plot_data.Format.astype('category')
plot_data.Format.cat.set_categories(['S','E'], inplace=True)
plot_data.Workload = plot_data.Workload.astype('category')
plot_data.Workload.cat.set_categories(['bal','imb','slc','iso'], inplace=True)
plot_data.sort_values(['Workload', 'Format', 'Strategy'], inplace=True)
plot_data
# Out:
# Images Workload Format  Strategy         20         40         60         80  \
# 2           bal      S         3   1.892004   2.282544   2.513664   2.933944
# 3           bal      S         4   6.089707   5.121941   4.735191   4.750330
# 0           bal      E         3   4.429180   4.885418   4.405545   4.539387
# 1           bal      E         4   9.661032   9.578474   8.553214   8.393490
# 6           imb      S         3   1.499561   1.772231   2.419403   2.587637
# 7           imb      S         4   5.481320   6.101561   6.321707   6.130891
# 4           imb      E         3   4.408279   5.324808   4.992480   5.204870
# 5           imb      E         4  16.711930  18.970486  19.337076  18.066623
# 14          slc      S         3   1.382271   1.462856   1.855826   1.922853
# 15          slc      S         4   5.712659   5.426244   5.088338   4.952841
# 12          slc      E         3   3.805310   5.553651   4.746872   4.998143
# 13          slc      E         4  16.623563  20.356316  22.033734  21.659090
# 10          iso      S         3   1.389251   1.566148   1.833714   1.692833
# 11          iso      S         4   5.347850   4.940055   5.197028   4.495581
# 8           iso      E         3   3.333430   3.978468   4.380927   4.649950
# 9           iso      E         4  13.924698  14.891250  13.398796  14.059942
#
# Images        100
# 2        2.932558
# 3        4.490810
# 0        4.450754
# 1        7.612073
# 6        2.662647
# 7        5.906745
# 4        5.410282
# 5       19.630067
# 14       2.263330
# 15       4.772914
# 12       5.316813
# 13      22.218501
# 10       1.982354
# 11       4.371103
# 8        4.885928
# 9       13.333687

# %% [markdown]
# Change the values to printable names.

# %%
plot_data.Workload = plot_data.Workload.map({'bal': 'Balanced',
                                             'imb': 'Imbalanced',
                                             'slc': 'Slice',
                                             'iso': 'Isosurface'})
plot_data.Format = plot_data.Format.map({'S': 'Static', 'E': 'Explorable'})
plot_data.rename(index=str, columns={'Strategy': 'Alg'}, inplace=True)
plot_data.rename(index=str, columns={'Format': 'Type'}, inplace=True)
plot_data
# Out:
# Images    Workload        Type  Alg         20         40         60  \
# 2         Balanced      Static    3   1.892004   2.282544   2.513664
# 3         Balanced      Static    4   6.089707   5.121941   4.735191
# 0         Balanced  Explorable    3   4.429180   4.885418   4.405545
# 1         Balanced  Explorable    4   9.661032   9.578474   8.553214
# 6       Imbalanced      Static    3   1.499561   1.772231   2.419403
# 7       Imbalanced      Static    4   5.481320   6.101561   6.321707
# 4       Imbalanced  Explorable    3   4.408279   5.324808   4.992480
# 5       Imbalanced  Explorable    4  16.711930  18.970486  19.337076
# 14           Slice      Static    3   1.382271   1.462856   1.855826
# 15           Slice      Static    4   5.712659   5.426244   5.088338
# 12           Slice  Explorable    3   3.805310   5.553651   4.746872
# 13           Slice  Explorable    4  16.623563  20.356316  22.033734
# 10      Isosurface      Static    3   1.389251   1.566148   1.833714
# 11      Isosurface      Static    4   5.347850   4.940055   5.197028
# 8       Isosurface  Explorable    3   3.333430   3.978468   4.380927
# 9       Isosurface  Explorable    4  13.924698  14.891250  13.398796
#
# Images         80        100
# 2        2.933944   2.932558
# 3        4.750330   4.490810
# 0        4.539387   4.450754
# 1        8.393490   7.612073
# 6        2.587637   2.662647
# 7        6.130891   5.906745
# 4        5.204870   5.410282
# 5       18.066623  19.630067
# 14       1.922853   2.263330
# 15       4.952841   4.772914
# 12       4.998143   5.316813
# 13      21.659090  22.218501
# 10       1.692833   1.982354
# 11       4.495581   4.371103
# 8        4.649950   4.885928
# 9       14.059942  13.333687

# %% [markdown]
# Duplicate value columns to put in bar chart.

# %%
plot_data.insert(4, 20, plot_data[20], allow_duplicates=True)
plot_data.insert(6, 40, plot_data[40], allow_duplicates=True)
plot_data.insert(8, 60, plot_data[60], allow_duplicates=True)
plot_data.insert(10, 80, plot_data[80], allow_duplicates=True)
plot_data.insert(12, 100, plot_data[100], allow_duplicates=True)
plot_data
# Out:
# Images    Workload        Type  Alg         20         20         40  \
# 2         Balanced      Static    3   1.892004   1.892004   2.282544
# 3         Balanced      Static    4   6.089707   6.089707   5.121941
# 0         Balanced  Explorable    3   4.429180   4.429180   4.885418
# 1         Balanced  Explorable    4   9.661032   9.661032   9.578474
# 6       Imbalanced      Static    3   1.499561   1.499561   1.772231
# 7       Imbalanced      Static    4   5.481320   5.481320   6.101561
# 4       Imbalanced  Explorable    3   4.408279   4.408279   5.324808
# 5       Imbalanced  Explorable    4  16.711930  16.711930  18.970486
# 14           Slice      Static    3   1.382271   1.382271   1.462856
# 15           Slice      Static    4   5.712659   5.712659   5.426244
# 12           Slice  Explorable    3   3.805310   3.805310   5.553651
# 13           Slice  Explorable    4  16.623563  16.623563  20.356316
# 10      Isosurface      Static    3   1.389251   1.389251   1.566148
# 11      Isosurface      Static    4   5.347850   5.347850   4.940055
# 8       Isosurface  Explorable    3   3.333430   3.333430   3.978468
# 9       Isosurface  Explorable    4  13.924698  13.924698  14.891250
#
# Images         40         60         60         80         80        100  \
# 2        2.282544   2.513664   2.513664   2.933944   2.933944   2.932558
# 3        5.121941   4.735191   4.735191   4.750330   4.750330   4.490810
# 0        4.885418   4.405545   4.405545   4.539387   4.539387   4.450754
# 1        9.578474   8.553214   8.553214   8.393490   8.393490   7.612073
# 6        1.772231   2.419403   2.419403   2.587637   2.587637   2.662647
# 7        6.101561   6.321707   6.321707   6.130891   6.130891   5.906745
# 4        5.324808   4.992480   4.992480   5.204870   5.204870   5.410282
# 5       18.970486  19.337076  19.337076  18.066623  18.066623  19.630067
# 14       1.462856   1.855826   1.855826   1.922853   1.922853   2.263330
# 15       5.426244   5.088338   5.088338   4.952841   4.952841   4.772914
# 12       5.553651   4.746872   4.746872   4.998143   4.998143   5.316813
# 13      20.356316  22.033734  22.033734  21.659090  21.659090  22.218501
# 10       1.566148   1.833714   1.833714   1.692833   1.692833   1.982354
# 11       4.940055   5.197028   5.197028   4.495581   4.495581   4.371103
# 8        3.978468   4.380927   4.380927   4.649950   4.649950   4.885928
# 9       14.891250  13.398796  13.398796  14.059942  14.059942  13.333687
#
# Images        100
# 2        2.932558
# 3        4.490810
# 0        4.450754
# 1        7.612073
# 6        2.662647
# 7        5.906745
# 4        5.410282
# 5       19.630067
# 14       2.263330
# 15       4.772914
# 12       5.316813
# 13      22.218501
# 10       1.982354
# 11       4.371103
# 8        4.885928
# 9       13.333687

# %%
max_value = plot_data.max()[3:].max()
max_value
# Out:
# 22.218501292934103

# %%
canvas = toyplot.Canvas(width=900, height=420)
table = canvas.table(plot_data)
table.cells.cell[:,3:].format = toyplot.format.FloatFormatter(format='{:.1f}')

# Generally I do not want vertical lines, but they can be handy when resizing columns.
#table.grid.vlines[...] = "single"

table.column(0).width = 72
table.column(1).width = 70
table.column(2).width = 25
table.column(3).width = 30
table.column(3).column_offset = 8
table.column(5).width = 30
table.column(5).column_offset = 8
table.column(7).width = 30
table.column(7).column_offset = 8
table.column(9).width = 30
table.column(9).column_offset = 8
table.column(11).width = 30
table.column(11).column_offset = 8

# Left align the text in cells, center algorithm number
table.body.cell[:, 0:2].align = 'left'
table.body.cell[:, 2].align = 'center'

# Merge header for numbers and bar chart
table.top.cell[0,3:5].merge().data = "20 Images"
table.top.cell[0,5:7].merge().data = "40 Images"
table.top.cell[0,7:9].merge().data = "60 Images"
table.top.cell[0,9:11].merge().data = "80 Images"
table.top.cell[0,11:13].merge().data = "100 Images"

# Make bar chart columns
axes = table.body.column[4].cartesian()
axes.cell_bars(width=1)
axes.x.domain.max = max_value

axes = table.body.column[6].cartesian()
axes.cell_bars(width=1)
axes.x.domain.max = max_value

axes = table.body.column[8].cartesian()
axes.cell_bars(width=1)
axes.x.domain.max = max_value

axes = table.body.column[10].cartesian()
axes.cell_bars(width=1)
axes.x.domain.max = max_value

axes = table.body.column[12].cartesian()
axes.cell_bars(width=1)
axes.x.domain.max = max_value

# Add gaps to separate groups
table.body.gaps.rows[[3,7,11]] = '6pt'
table.body.gaps.rows[[1,5,9,13]] = '3pt'
# Out:
# <div align="center" class="toyplot" id="t32ac3d8631684000aedcdb240347bbab"><svg class="toyplot-canvas-Canvas" height="420.0px" id="t3c58a6e7b95847858bfda631d52919ec" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 900.0 420.0" width="900.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink"><g class="toyplot-coordinates-Table" id="tf1a50a18837a454c9ed1c98386675f55"><text style="dominant-baseline:middle;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-size:12px;font-weight:bold;stroke:none;text-anchor:middle" transform="translate(86.0,58.235294117647058)"><tspan style="dominant-baseline:inherit">Workload</tspan></text><text style="dominant-baseline:middle;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-size:12px;font-weight:bold;stroke:none;text-anchor:middle" transform="translate(157.0,58.235294117647058)"><tspan style="dominant-baseline:inherit">Type</tspan></text><text style="dominant-baseline:middle;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-size:12px;font-weight:bold;stroke:none;text-anchor:end" transform="translate(212.0,58.235294117647058)"><tspan style="dominant-baseline:inherit">Alg</tspan></text><text style="dominant-baseline:middle;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-size:12px;stroke:none;text-anchor:begin" transform="translate(55.0,74.705882352941174)"><tspan style="dominant-baseline:inherit">Balanced</tspan></text><text style="dominant-baseline:middle;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-size:12px;stroke:none;text-anchor:begin" transform="translate(127.0,74.705882352941174)"><tspan style="dominant-baseline:inherit">Static</tspan></text><text style="dominant-baseline:middle;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-size:12px;stroke:none;text-anchor:middle" transform="translate(204.5,74.705882352941174)"><tspan style="dominant-baseline:inherit">3</tspan></text><text style="dominant-baseline:middle;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-size:12px;stroke:none;text-anchor:end" transform="translate(230.0,74.705882352941174)translate(8.0,0)"><tspan style="dominant-baseline:inherit">1</tspan></text><text style="dominant-baseline:middle;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-size:12px;stroke:none;text-anchor:middle" transform="translate(232.0,74.705882352941174)translate(8.0,0)"><tspan style="dominant-baseline:inherit">.</tspan></text><text style="dominant-baseline:middle;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-size:12px;stroke:none;text-anchor:begin" transform="translate(234.0,74.705882352941174)translate(8.0,0)"><tspan style="dominant-baseline:inherit">9</tspan></text><text style="dominant-baseline:middle;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-size:12px;stroke:none;text-anchor:end" transform="translate(356.60000000000002,74.705882352941174)translate(8.0,0)"><tspan style="dominant-baseline:inherit">2</tspan></text><text style="dominant-baseline:middle;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-size:12px;stroke:none;text-anchor:middle" transform="translate(358.60000000000002,74.705882352941174)translate(8.0,0)"><tspan style="dominant-baseline:inherit">.</tspan></text><text style="dominant-baseline:middle;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-size:12px;stroke:none;text-anchor:begin" transform="translate(360.60000000000002,74.705882352941174)translate(8.0,0)"><tspan style="dominant-baseline:inherit">3</tspan></text><text style="dominant-baseline:middle;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-size:12px;stroke:none;text-anchor:end" transform="translate(483.20000000000005,74.705882352941174)translate(8.0,0)"><tspan style="dominant-baseline:inherit">2</tspan></text><text style="dominant-baseline:middle;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0; ...

# %%
toyplot.pdf.render(canvas, 'Compositing_SpeedUp_Inverse_Cinema.pdf')
