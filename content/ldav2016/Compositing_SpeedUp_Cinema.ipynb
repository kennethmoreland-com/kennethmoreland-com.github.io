# %% [markdown]
# This was written with Toyplot 0.13. It definitely won't work with older versions.

# %%
import numpy
import pandas
import toyplot.pdf

print toyplot.__version__
# Out:
# 0.13.0

# %% [markdown]
# Read in the data from a csv file.

# %%
data = pandas.read_csv('All_Compositing_SpeedUp.csv')
#data

# %% [markdown]
# Construct the plot for the "Cinema" camera.

# %%
subset_data = data[data.Camera == 'cinema']
subset_data = subset_data[subset_data.Strategy >= 3]
plot_data = subset_data.pivot_table(index=['Workload','Format','Strategy'],
                                    columns='Images',
                                    values='Speedup')
plot_data.reset_index(inplace=True)
plot_data
# Out:
# Images Workload Format  Strategy         20         40         60         80  \
# 0           bal      E         3   4.101920   5.059599   4.796521   5.143578
# 1           bal      E         4  13.962251  15.326799  15.488477  14.957164
# 2           bal      S         3   1.325691   1.554727   1.789179   1.922113
# 3           bal      S         4   4.766769   4.375294   4.208218   3.999053
# 4           imb      E         3   3.899729   5.195816   4.780779   4.805884
# 5           imb      E         4  14.472616  17.305725  17.475601  16.956842
# 6           imb      S         3   1.297892   1.963084   1.772427   2.008103
# 7           imb      S         4   4.954372   5.667480   4.236737   4.447056
# 8           iso      E         3   3.294012   3.859435   4.378958   4.604058
# 9           iso      E         4  14.242830  14.237549  14.075540  13.918929
# 10          iso      S         3   1.257036   1.484213   1.812371   1.584537
# 11          iso      S         4   5.506112   4.747262   4.626360   4.110453
# 12          slc      E         3   3.972394   4.852111   4.663443   4.950108
# 13          slc      E         4  14.644099  16.634894  17.301707  17.517453
# 14          slc      S         3   1.323646   1.700031   1.684217   1.891043
# 15          slc      S         4   5.348749   5.005539   4.634585   4.332105
#
# Images        100
# 0        5.016837
# 1       15.133640
# 2        1.885186
# 3        3.764614
# 4        5.026230
# 5       17.164581
# 6        1.949649
# 7        4.145752
# 8        4.959632
# 9       13.947572
# 10       1.868467
# 11       4.055115
# 12       5.138965
# 13      17.608311
# 14       2.122800
# 15       4.269345

# %% [markdown]
# Change order of entries.

# %%
plot_data.Format = plot_data.Format.astype('category')
plot_data.Format.cat.set_categories(['S','E'], inplace=True)
plot_data.Workload = plot_data.Workload.astype('category')
plot_data.Workload.cat.set_categories(['bal','imb','slc','iso'], inplace=True)
plot_data.sort_values(['Workload', 'Format', 'Strategy'], inplace=True)
plot_data
# Out:
# Images Workload Format  Strategy         20         40         60         80  \
# 2           bal      S         3   1.325691   1.554727   1.789179   1.922113
# 3           bal      S         4   4.766769   4.375294   4.208218   3.999053
# 0           bal      E         3   4.101920   5.059599   4.796521   5.143578
# 1           bal      E         4  13.962251  15.326799  15.488477  14.957164
# 6           imb      S         3   1.297892   1.963084   1.772427   2.008103
# 7           imb      S         4   4.954372   5.667480   4.236737   4.447056
# 4           imb      E         3   3.899729   5.195816   4.780779   4.805884
# 5           imb      E         4  14.472616  17.305725  17.475601  16.956842
# 14          slc      S         3   1.323646   1.700031   1.684217   1.891043
# 15          slc      S         4   5.348749   5.005539   4.634585   4.332105
# 12          slc      E         3   3.972394   4.852111   4.663443   4.950108
# 13          slc      E         4  14.644099  16.634894  17.301707  17.517453
# 10          iso      S         3   1.257036   1.484213   1.812371   1.584537
# 11          iso      S         4   5.506112   4.747262   4.626360   4.110453
# 8           iso      E         3   3.294012   3.859435   4.378958   4.604058
# 9           iso      E         4  14.242830  14.237549  14.075540  13.918929
#
# Images        100
# 2        1.885186
# 3        3.764614
# 0        5.016837
# 1       15.133640
# 6        1.949649
# 7        4.145752
# 4        5.026230
# 5       17.164581
# 14       2.122800
# 15       4.269345
# 12       5.138965
# 13      17.608311
# 10       1.868467
# 11       4.055115
# 8        4.959632
# 9       13.947572

# %% [markdown]
# Change the values to printable names.

# %%
plot_data.Workload = plot_data.Workload.map({'bal': 'Balanced',
                                             'imb': 'Imbalanced',
                                             'slc': 'Slice',
                                             'iso': 'Isosurface'})
plot_data.Format = plot_data.Format.map({'S': 'Static', 'E': 'Explorable'})
plot_data.rename(index=str, columns={'Strategy': 'Alg'}, inplace=True)
plot_data.rename(index=str, columns={'Format': 'Type'}, inplace=True)
plot_data
# Out:
# Images    Workload        Type  Alg         20         40         60  \
# 2         Balanced      Static    3   1.325691   1.554727   1.789179
# 3         Balanced      Static    4   4.766769   4.375294   4.208218
# 0         Balanced  Explorable    3   4.101920   5.059599   4.796521
# 1         Balanced  Explorable    4  13.962251  15.326799  15.488477
# 6       Imbalanced      Static    3   1.297892   1.963084   1.772427
# 7       Imbalanced      Static    4   4.954372   5.667480   4.236737
# 4       Imbalanced  Explorable    3   3.899729   5.195816   4.780779
# 5       Imbalanced  Explorable    4  14.472616  17.305725  17.475601
# 14           Slice      Static    3   1.323646   1.700031   1.684217
# 15           Slice      Static    4   5.348749   5.005539   4.634585
# 12           Slice  Explorable    3   3.972394   4.852111   4.663443
# 13           Slice  Explorable    4  14.644099  16.634894  17.301707
# 10      Isosurface      Static    3   1.257036   1.484213   1.812371
# 11      Isosurface      Static    4   5.506112   4.747262   4.626360
# 8       Isosurface  Explorable    3   3.294012   3.859435   4.378958
# 9       Isosurface  Explorable    4  14.242830  14.237549  14.075540
#
# Images         80        100
# 2        1.922113   1.885186
# 3        3.999053   3.764614
# 0        5.143578   5.016837
# 1       14.957164  15.133640
# 6        2.008103   1.949649
# 7        4.447056   4.145752
# 4        4.805884   5.026230
# 5       16.956842  17.164581
# 14       1.891043   2.122800
# 15       4.332105   4.269345
# 12       4.950108   5.138965
# 13      17.517453  17.608311
# 10       1.584537   1.868467
# 11       4.110453   4.055115
# 8        4.604058   4.959632
# 9       13.918929  13.947572

# %% [markdown]
# Duplicate value columns to put in bar chart.

# %%
plot_data.insert(4, 20, plot_data[20], allow_duplicates=True)
plot_data.insert(6, 40, plot_data[40], allow_duplicates=True)
plot_data.insert(8, 60, plot_data[60], allow_duplicates=True)
plot_data.insert(10, 80, plot_data[80], allow_duplicates=True)
plot_data.insert(12, 100, plot_data[100], allow_duplicates=True)
plot_data
# Out:
# Images    Workload        Type  Alg         20         20         40  \
# 2         Balanced      Static    3   1.325691   1.325691   1.554727
# 3         Balanced      Static    4   4.766769   4.766769   4.375294
# 0         Balanced  Explorable    3   4.101920   4.101920   5.059599
# 1         Balanced  Explorable    4  13.962251  13.962251  15.326799
# 6       Imbalanced      Static    3   1.297892   1.297892   1.963084
# 7       Imbalanced      Static    4   4.954372   4.954372   5.667480
# 4       Imbalanced  Explorable    3   3.899729   3.899729   5.195816
# 5       Imbalanced  Explorable    4  14.472616  14.472616  17.305725
# 14           Slice      Static    3   1.323646   1.323646   1.700031
# 15           Slice      Static    4   5.348749   5.348749   5.005539
# 12           Slice  Explorable    3   3.972394   3.972394   4.852111
# 13           Slice  Explorable    4  14.644099  14.644099  16.634894
# 10      Isosurface      Static    3   1.257036   1.257036   1.484213
# 11      Isosurface      Static    4   5.506112   5.506112   4.747262
# 8       Isosurface  Explorable    3   3.294012   3.294012   3.859435
# 9       Isosurface  Explorable    4  14.242830  14.242830  14.237549
#
# Images         40         60         60         80         80        100  \
# 2        1.554727   1.789179   1.789179   1.922113   1.922113   1.885186
# 3        4.375294   4.208218   4.208218   3.999053   3.999053   3.764614
# 0        5.059599   4.796521   4.796521   5.143578   5.143578   5.016837
# 1       15.326799  15.488477  15.488477  14.957164  14.957164  15.133640
# 6        1.963084   1.772427   1.772427   2.008103   2.008103   1.949649
# 7        5.667480   4.236737   4.236737   4.447056   4.447056   4.145752
# 4        5.195816   4.780779   4.780779   4.805884   4.805884   5.026230
# 5       17.305725  17.475601  17.475601  16.956842  16.956842  17.164581
# 14       1.700031   1.684217   1.684217   1.891043   1.891043   2.122800
# 15       5.005539   4.634585   4.634585   4.332105   4.332105   4.269345
# 12       4.852111   4.663443   4.663443   4.950108   4.950108   5.138965
# 13      16.634894  17.301707  17.301707  17.517453  17.517453  17.608311
# 10       1.484213   1.812371   1.812371   1.584537   1.584537   1.868467
# 11       4.747262   4.626360   4.626360   4.110453   4.110453   4.055115
# 8        3.859435   4.378958   4.378958   4.604058   4.604058   4.959632
# 9       14.237549  14.075540  14.075540  13.918929  13.918929  13.947572
#
# Images        100
# 2        1.885186
# 3        3.764614
# 0        5.016837
# 1       15.133640
# 6        1.949649
# 7        4.145752
# 4        5.026230
# 5       17.164581
# 14       2.122800
# 15       4.269345
# 12       5.138965
# 13      17.608311
# 10       1.868467
# 11       4.055115
# 8        4.959632
# 9       13.947572

# %%
max_value = plot_data.max()[3:].max()
max_value
# Out:
# 17.6083113571159

# %%
canvas = toyplot.Canvas(width=900, height=420)
table = canvas.table(plot_data)
table.cells.cell[:,3:].format = toyplot.format.FloatFormatter(format='{:.1f}')

# Generally I do not want vertical lines, but they can be handy when resizing columns.
#table.grid.vlines[...] = "single"

table.column(0).width = 72
table.column(1).width = 70
table.column(2).width = 25
table.column(3).width = 30
table.column(3).column_offset = 8
table.column(5).width = 30
table.column(5).column_offset = 8
table.column(7).width = 30
table.column(7).column_offset = 8
table.column(9).width = 30
table.column(9).column_offset = 8
table.column(11).width = 30
table.column(11).column_offset = 8

# Left align the text in cells, center algorithm number
table.body.cell[:, 0:2].align = 'left'
table.body.cell[:, 2].align = 'center'

# Merge header for numbers and bar chart
table.top.cell[0,3:5].merge().data = "20 Images"
table.top.cell[0,5:7].merge().data = "40 Images"
table.top.cell[0,7:9].merge().data = "60 Images"
table.top.cell[0,9:11].merge().data = "80 Images"
table.top.cell[0,11:13].merge().data = "100 Images"

# Make bar chart columns
axes = table.body.column[4].cartesian()
axes.cell_bars(width=1)
axes.x.domain.max = max_value

axes = table.body.column[6].cartesian()
axes.cell_bars(width=1)
axes.x.domain.max = max_value

axes = table.body.column[8].cartesian()
axes.cell_bars(width=1)
axes.x.domain.max = max_value

axes = table.body.column[10].cartesian()
axes.cell_bars(width=1)
axes.x.domain.max = max_value

axes = table.body.column[12].cartesian()
axes.cell_bars(width=1)
axes.x.domain.max = max_value

# Add gaps to separate groups
table.body.gaps.rows[[3,7,11]] = '6pt'
table.body.gaps.rows[[1,5,9,13]] = '3pt'
# Out:
# <div align="center" class="toyplot" id="t486f471e61074d139655c915927e12d2"><svg class="toyplot-canvas-Canvas" height="420.0px" id="td21fdb074e05496d9cefbe20db92be9b" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 900.0 420.0" width="900.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink"><g class="toyplot-coordinates-Table" id="t0797fa6934704e7f8a1faf3a228c2d74"><text style="dominant-baseline:middle;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-size:12px;font-weight:bold;stroke:none;text-anchor:middle" transform="translate(86.0,58.235294117647058)"><tspan style="dominant-baseline:inherit">Workload</tspan></text><text style="dominant-baseline:middle;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-size:12px;font-weight:bold;stroke:none;text-anchor:middle" transform="translate(157.0,58.235294117647058)"><tspan style="dominant-baseline:inherit">Type</tspan></text><text style="dominant-baseline:middle;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-size:12px;font-weight:bold;stroke:none;text-anchor:end" transform="translate(212.0,58.235294117647058)"><tspan style="dominant-baseline:inherit">Alg</tspan></text><text style="dominant-baseline:middle;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-size:12px;stroke:none;text-anchor:begin" transform="translate(55.0,74.705882352941174)"><tspan style="dominant-baseline:inherit">Balanced</tspan></text><text style="dominant-baseline:middle;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-size:12px;stroke:none;text-anchor:begin" transform="translate(127.0,74.705882352941174)"><tspan style="dominant-baseline:inherit">Static</tspan></text><text style="dominant-baseline:middle;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-size:12px;stroke:none;text-anchor:middle" transform="translate(204.5,74.705882352941174)"><tspan style="dominant-baseline:inherit">3</tspan></text><text style="dominant-baseline:middle;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-size:12px;stroke:none;text-anchor:end" transform="translate(230.0,74.705882352941174)translate(8.0,0)"><tspan style="dominant-baseline:inherit">1</tspan></text><text style="dominant-baseline:middle;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-size:12px;stroke:none;text-anchor:middle" transform="translate(232.0,74.705882352941174)translate(8.0,0)"><tspan style="dominant-baseline:inherit">.</tspan></text><text style="dominant-baseline:middle;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-size:12px;stroke:none;text-anchor:begin" transform="translate(234.0,74.705882352941174)translate(8.0,0)"><tspan style="dominant-baseline:inherit">3</tspan></text><text style="dominant-baseline:middle;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-size:12px;stroke:none;text-anchor:end" transform="translate(356.60000000000002,74.705882352941174)translate(8.0,0)"><tspan style="dominant-baseline:inherit">1</tspan></text><text style="dominant-baseline:middle;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-size:12px;stroke:none;text-anchor:middle" transform="translate(358.60000000000002,74.705882352941174)translate(8.0,0)"><tspan style="dominant-baseline:inherit">.</tspan></text><text style="dominant-baseline:middle;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-size:12px;stroke:none;text-anchor:begin" transform="translate(360.60000000000002,74.705882352941174)translate(8.0,0)"><tspan style="dominant-baseline:inherit">6</tspan></text><text style="dominant-baseline:middle;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-size:12px;stroke:none;text-anchor:end" transform="translate(483.20000000000005,74.705882352941174)translate(8.0,0)"><tspan style="dominant-baseline:inherit">1</tspan></text><text style="dominant-baseline:middle;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0; ...

# %%
toyplot.pdf.render(canvas, 'Compositing_SpeedUp_Cinema.pdf')
