# %% [markdown]
# # Scaling from [Habib2013]

# %% [markdown]
# This document demonstrates taking some of the scaling data from Habib et al. (2013) and presenting it to show the scaling performance well. These plots demonstrate the metrics outlined in "[Formal Metrics for Large-Scale Parallel Performance](http://www.kennethmoreland.com/parallel-scaling-metrics/)" by Moreland and Oldfield.

# %% [markdown]
# ## Loading the Data

# %% [markdown]
# First the preliminaries. Here are the Python modules we depend on.

# %%
import numpy
import pandas
import toyplot.pdf

# %% [markdown]
# Read in the raw data file [Habib2013FullTitanRaw.csv](Habib2013FullTitanRaw.csv). This is timing data ripped from the [Habib2013] paper by measuring the locations of the measurements in Figure 3. The measurements were made using rules in Adobe Acrobat, so should be as accurate as they are placed in the figure.

# %%
data = pandas.read_csv('Habib2013FullTitanRaw.csv')
data
# Out:
#      Study  Number of Nodes  Plot measure (pixels)
# 0   Strong               32                 50.632
# 1   Strong               64                 43.277
# 2   Strong              128                 36.018
# 3   Strong              256                 28.098
# 4   Strong              512                 19.848
# 5   Strong             1024                 13.577
# 6   Strong             2048                  9.617
# 7   Strong             4096                  7.826
# 8   Strong             8192                  2.734
# 9     Weak              128                 30.879
# 10    Weak              256                 24.892
# 11    Weak              512                 16.877
# 12    Weak             1024                  6.601
# 13    Weak             2048                  1.367
# 14    Weak             4096                 -6.647
# 15    Weak             8192                -15.888
# 16    Weak            16384                -21.969

# %% [markdown]
# Our metrics need to know the data size for each measurement. According to the paper, the strong scaling measurements were all done with a 1024^3 grid of particles. The weak scaling had 32 million particles per node.

# %%
particles = numpy.empty(len(data.index))

strong_indices = numpy.array(data['Study'] == 'Strong')
particles[strong_indices] = 1024 ** 3

weak_indices = numpy.array(data['Study'] == 'Weak')
particles[weak_indices] = 32000000*data['Number of Nodes'][weak_indices]

data['particles'] = particles

# %% [markdown]
# The raw measurements are in screen pixels when the measurements were taken. When taking these measurements, I also measured the unit height (the height between tics) as 28.003 pixels per log(ns per particle). Use this to convert the plot measure to the actual value of nanoseconds per particle.

# %%
data['nanoseconds per particle'] = 10 ** (data['Plot measure (pixels)']/28.003)

# %% [markdown]
# With the nanoseconds per particle and the number of particle, we can derive what the actual time was.

# %%
data['seconds'] = (data['nanoseconds per particle']*1e-9)*data['particles']

# %% [markdown]
# ## Derived Metrics

# %% [markdown]
# We now have plenty of data to compute the rate. We can actually do it two ways. The rate is simply the inverse of the 'nanoseconds per particle' column (which we scale to particles per second). We can also compute the rate as the 'particles' column divided by the 'seconds' column. We compute both ways. One is saved and the other is used to check the error, which should be very low. We compute the error as an l2 norm.

# %%
data['rate'] = 1e9/data['nanoseconds per particle']

rate_check = data['particles']/data['seconds']

rate_error = numpy.linalg.norm(data['rate']-rate_check, ord=2)
rate_error
# Out:
# 2.7677678497145637e-07

# %% [markdown]
# The cost is defined as the time taken times the number of processing elements used. The cost per unit is the cost divided by the problem size (in this case, the number of particles). Some of our other caculations also require knowing the best cost per unit.

# %%
data['cost'] = data['seconds']*data['Number of Nodes']
data['cost per unit'] = data['cost']/data['particles']
best_cost_per_unit = numpy.min(data['cost per unit'])
best_cost_per_unit
# Out:
# 1.6214861797231084e-06

# %% [markdown]
# The efficiency can be expressed as the the best cost per unit divided by the observed cost per unit.

# %%
data['efficiency'] = best_cost_per_unit/data['cost per unit']

# %% [markdown]
# We can also use the ideal rate for comparison purposes. We also want the ideal value for 'nanoseconds per particle' as given in the original paper.

# %%
data['ideal rate'] = data['Number of Nodes']/best_cost_per_unit
data['ideal nanoseconds per particle'] = 1e9/data['ideal rate']

# %% [markdown]
# ## Standard Time Plot

# %% [markdown]
# Make a typical plot of time with linear scaling of the axis.

# %%
time_series = data.pivot_table(index='Number of Nodes',
                               columns='Study',
                               values='seconds')
time_series
# Out:
# Study               Strong       Weak
# Number of Nodes
# 32               69.022687        NaN
# 64               37.700007        NaN
# 128              20.754831  51.887558
# 256              10.821622  63.429999
# 512               5.491375  65.630448
# 1024              3.278995  56.386440
# 2048              2.367704  73.332439
# 4096              2.043478  75.882652
# 8192              1.344412  70.985908
# 16384                  NaN  86.108660

# %%
canvas = toyplot.Canvas(400, 320)
axes = canvas.axes(xscale='linear',
                   yscale='linear',
                   xlabel='Number of Nodes',
                   ylabel='Time (seconds)')
axes.x.ticks.locator = toyplot.locator.Explicit(numpy.arange(0,2**14+2**12,2**12))
axes.x.ticks.show = True
axes.y.ticks.show = True

x = time_series.index.values
y = numpy.column_stack((time_series['Weak'], time_series['Strong']))
axes.plot(x, y, marker='o', size=40)
axes.text(16384, time_series['Weak'][16384], 'Weak Scaling',
          style={'text-anchor':'end', 'baseline-shift':'-80%'},
          angle=13.5)
axes.text(8192+300, time_series['Strong'][8192], 'Strong Scaling',
          style={'text-anchor':'start'})
# Out:
# <div align="center" class="toyplot" id="tc8b41da5637e4dd5981e30b8836d637a"><svg height="320.0px" id="tded7ca048cb549239b200a4c84ef3e99" preserveAspectRatio="xMidyMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 400.0 320.0" width="400.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-axes-Cartesian" id="t9604766303514c07aa56c4666d938df9"><clipPath id="te404115df5124dc6bbd6133cb0d152a4"><rect height="220.0" width="300.0" x="50.0" y="50.0"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#te404115df5124dc6bbd6133cb0d152a4)" style="cursor:crosshair"><rect height="220.0" style="pointer-events:all;visibility:hidden" width="300.0" x="50.0" y="50.0"></rect><g class="toyplot-mark-Plot" id="t7aaa11391780418db830f9a76965bb97" style="fill:none"><g class="toyplot-Series"><path d="M 61.958127540539365 143.58127742232662 L 63.916255081078717 118.26849454871623 L 67.832510162157433 113.44287071130745 L 75.665020324314867 133.71514622163988 L 91.330040648629748 96.552263997487472 L 122.6600812972595 90.959600001372081 L 185.32016259451899 101.69824947794329 L 310.64032518903798 68.533779276199269" style="fill:none;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0;stroke-width:2.0"></path><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0"><circle cx="61.958127540539365" cy="143.58127742232662" r="3.1622776601683795"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0"><circle cx="63.916255081078717" cy="118.26849454871623" r="3.1622776601683795"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0"><circle cx="67.832510162157433" cy="113.44287071130745" r="3.1622776601683795"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0"><circle cx="75.665020324314867" cy="133.71514622163988" r="3.1622776601683795"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0"><circle cx="91.330040648629748" cy="96.552263997487472" r="3.1622776601683795"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0"><circle cx="122.6600812972595" cy="90.959600001372081" r="3.1622776601683795"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0"><circle cx="185.32016259451899" cy="101.69824947794329" r="3.1622776601683795"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0"><circle cx="310.64032518903798" cy="68.533779276199269" r="3.1622776601683795"></circle></g></g><g class="toyplot-Series"><path d="M 60.489531885134838 106.0036287403602 L 60.979063770269683 174.69483386807337 L 61.958127540539365 211.85591188159742 L 63.916255081078717 233.63961948811405 L 67.832510162157433 245.32894891879965 L 75.665020324314867 250.1807371434646 L 91.330040648629748 252.17921583679282 L 122.6600812972595 252.89024917441719 L 185.32016259451899 254.42331395950094" style="fill:none;stroke:rgb(98.8%,55.3%,38.4%);stroke-opacity:1.0;stroke-width:2.0"></path><g class="toyplot-Datum" style="fill:rgb(98.8%,55.3%,38.4%);fill-opacity:1.0;opacity:1.0;stroke:rgb(98.8%,55.3%,38.4%);stroke-opacity:1.0"><circle cx="60.489531885134838" cy="106.0036287403602" r="3.1622776601683795"></circle></g><g class="toyplot-Datum" style="f ...

# %% [markdown]
# Save the plot as [HabibTime.pdf](HabibTime.pdf).

# %%
toyplot.pdf.render(canvas, 'HabibTime.pdf')

# %% [markdown]
# ## Original Plot

# %% [markdown]
# Here we reproduce the original plot in the paper. The one difference is what we use as the ideal nanoseconds per particle. We use the ideal rate as measured from the algorithm. I believe the paper estimated the ideal based on the maximum FLOP rate of the computer vs. the FLOP rate while running the algorithm.

# %%
original_series = data.pivot_table(index='Number of Nodes',
                                   columns='Study',
                                   values='nanoseconds per particle',
                                   aggfunc=numpy.mean)
original_series
# Out:
# Study               Strong       Weak
# Number of Nodes
# 32               64.282386        NaN
# 64               35.110867        NaN
# 128              19.329443  12.667861
# 256              10.078421   7.742920
# 512               5.114241   4.005765
# 1024              3.053802   1.720778
# 2048              2.205096   1.118964
# 4096              1.903137   0.578939
# 8192              1.252081   0.270790
# 16384                  NaN   0.164239

# %%
canvas = toyplot.Canvas(400, 320)
axes = canvas.axes(xscale='log2',
                   yscale='log10',
                   xlabel='Number of Nodes',
                   ylabel='Nanoseconds per Particle')
axes.x.ticks.locator = toyplot.locator.Explicit(2 ** numpy.arange(5,15))
axes.y.ticks.locator = toyplot.locator.Explicit(10 ** numpy.arange(-1,2, dtype=numpy.float64))
axes.x.ticks.show = True
axes.y.ticks.show = True

x = original_series.index.values
y = numpy.column_stack((original_series['Weak'], original_series['Strong']))
axes.plot(x, y, marker='o', size=40)
axes.text(16384, original_series['Weak'][16384], 'Weak Scaling',
          style={'text-anchor':'end', 'baseline-shift':'80%'},
          angle=-32)
axes.text(8192, original_series['Strong'][8192], 'Strong Scaling',
          style={'baseline-shift':'80%'},
          angle=-22.5)

# The easiest way to plot the ideal curve is to sort the original data by the number of
# nodes (the x axis) and plot that column directly.
ideal_order = numpy.argsort(data['Number of Nodes'])
axes.plot(data['Number of Nodes'][ideal_order],
          data['ideal nanoseconds per particle'][ideal_order],
          style={'stroke':'gray', 'stroke-width':0.5, 'stroke-dasharray':'5,5'})
axes.text(8192, 0.198, 'Ideal',
          style={'baseline-shift':'-75%', 'color':'gray'},
          angle=-34.5)
# Out:
# <div align="center" class="toyplot" id="tc6a3a3238c3c4293847e8a244f377b18"><svg height="320.0px" id="tc9fc586bb59d4965ac71eff3d3df0874" preserveAspectRatio="xMidyMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 400.0 320.0" width="400.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-axes-Cartesian" id="t175e9623e30d4dcebc8ea88beb8af849"><clipPath id="td56f6074271a4d3b8df21b6837eaa905"><rect height="220.0" width="300.0" x="50.0" y="50.0"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#td56f6074271a4d3b8df21b6837eaa905)" style="cursor:crosshair"><rect height="220.0" style="pointer-events:all;visibility:hidden" width="300.0" x="50.0" y="50.0"></rect><g class="toyplot-mark-Plot" id="tb94f128a40bb47cc9d163cc832b7240e" style="fill:none"><g class="toyplot-Series"><path d="M 112.40323507852996 108.24435676855234 L 138.60485261779493 122.86689329329914 L 164.80647015705992 142.44257898660891 L 191.00808769632488 167.54048867899206 L 217.20970523558987 180.32391212487886 L 243.41132277485485 199.8971554369418 L 269.61294031411984 222.46720053886011 L 295.81455785338483 237.31932090080849" style="fill:none;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0;stroke-width:2.0"></path><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0"><circle cx="112.40323507852996" cy="108.24435676855234" r="3.1622776601683795"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0"><circle cx="138.60485261779493" cy="122.86689329329914" r="3.1622776601683795"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0"><circle cx="164.80647015705992" cy="142.44257898660891" r="3.1622776601683795"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0"><circle cx="191.00808769632488" cy="167.54048867899206" r="3.1622776601683795"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0"><circle cx="217.20970523558987" cy="180.32391212487886" r="3.1622776601683795"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0"><circle cx="243.41132277485485" cy="199.8971554369418" r="3.1622776601683795"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0"><circle cx="269.61294031411984" cy="222.46720053886011" r="3.1622776601683795"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0"><circle cx="295.81455785338483" cy="237.31932090080849" r="3.1622776601683795"></circle></g></g><g class="toyplot-Series"><path d="M 60.0 60.0 L 86.201617539264987 77.963714070404649 L 112.40323507852996 95.692959541113964 L 138.60485261779493 115.03661901597522 L 164.80647015705992 135.18626430228906 L 191.00808769632488 150.5024371011344 L 217.20970523558987 160.17426683856505 L 243.41132277485485 164.54857165163025 L 269.61294031411984 176.98517696046784" style="fill:none;stroke:rgb(98.8%,55.3%,38.4%);stroke-opacity:1.0;stroke-width:2.0"></path><g class="toyplot-Datum" style="fill:rgb(98.8%,55.3%,38.4%);fill-opacity:1.0;opacity:1.0;stroke:rgb(98.8%,55.3%,38.4%);stroke-opacity:1.0"><circle cx="60.0" cy="60.0" r="3.1622776601683795"></circle></g><g class="toyplot-Datum" style="fill:rgb(98.8%,55.3%,38.4%);fill-opacity:1.0;opacity:1 ...

# %% [markdown]
# Save the plot as [HabibTimePerParticle.pdf](HabibTimePerParticle.pdf).

# %%
toyplot.pdf.render(canvas, 'HabibTimePerParticle.pdf')

# %% [markdown]
# ## Rate Plot

# %%
rate_series = data.pivot_table(index='Number of Nodes',
                               columns='Study',
                               values='rate')
rate_series
# Out:
# Study                  Strong          Weak
# Number of Nodes
# 32               1.555636e+07           NaN
# 64               2.848121e+07           NaN
# 128              5.173455e+07  7.893993e+07
# 256              9.922189e+07  1.291502e+08
# 512              1.955324e+08  2.496402e+08
# 1024             3.274606e+08  5.811326e+08
# 2048             4.534950e+08  8.936836e+08
# 4096             5.254482e+08  1.727299e+09
# 8192             7.986704e+08  3.692902e+09
# 16384                     NaN  6.088679e+09

# %%
data['ideal rate']
# Out:
# 0     1.973498e+07
# 1     3.946996e+07
# 2     7.893993e+07
# 3     1.578799e+08
# 4     3.157597e+08
# 5     6.315194e+08
# 6     1.263039e+09
# 7     2.526078e+09
# 8     5.052155e+09
# 9     7.893993e+07
# 10    1.578799e+08
# 11    3.157597e+08
# 12    6.315194e+08
# 13    1.263039e+09
# 14    2.526078e+09
# 15    5.052155e+09
# 16    1.010431e+10
# Name: ideal rate, dtype: float64

# %%
canvas = toyplot.Canvas(400, 320)
axes = canvas.axes(xscale='linear',
                   yscale='linear',
                   xlabel='Number of Nodes',
                   ylabel='Rate (billion particles/second)')
axes.x.ticks.locator = toyplot.locator.Explicit(numpy.arange(0,2**14+2**12,2**12))
axes.x.ticks.show = True
axes.y.ticks.show = True

x = rate_series.index.values
y = numpy.column_stack((rate_series['Weak']/1e9, rate_series['Strong']/1e9))
axes.plot(x, y, marker='o', size=40)
axes.text(16384, rate_series['Weak'][16384]/1e9, 'Weak Scaling',
          style={'text-anchor':'end', 'baseline-shift':'80%'},
          angle=21)
axes.text(8192+300, rate_series['Strong'][8192]/1e9, 'Strong Scaling',
          style={'text-anchor':'start'})

# The easiest way to plot the ideal curve is to sort the original data by the number of
# nodes (the x axis) and plot that column directly.
ideal_order = numpy.argsort(data['Number of Nodes'])
axes.plot(data['Number of Nodes'][ideal_order],
          data['ideal rate'][ideal_order]/1e9,
          style={'stroke':'gray', 'stroke-width':0.5, 'stroke-dasharray':'5,5'})
axes.text(16384, 10.1, 'Ideal',
          style={'text-anchor':'end', 'baseline-shift':'-75%', 'color':'gray'},
          angle=35.5)
# Out:
# <div align="center" class="toyplot" id="t2684cdc086cf466385512b950c305775"><svg height="320.0px" id="t7223717ff7fe4f80abfc29a54c83f698" preserveAspectRatio="xMidyMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 400.0 320.0" width="400.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-axes-Cartesian" id="t3ef6f90fac8c4d3c9fd5c1d7b0f23814"><clipPath id="t10e29a004ac6438fa46752918217d1e7"><rect height="220.0" width="300.0" x="50.0" y="50.0"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#t10e29a004ac6438fa46752918217d1e7)" style="cursor:crosshair"><rect height="220.0" style="pointer-events:all;visibility:hidden" width="300.0" x="50.0" y="50.0"></rect><g class="toyplot-mark-Plot" id="tafd14b5b84b64cb8bd092aabf9de5b98" style="fill:none"><g class="toyplot-Series"><path d="M 61.958127540539365 258.4375 L 63.916255081078717 257.44366040051301 L 67.832510162157433 255.0587380091398 L 75.665020324314867 248.49733255508005 L 91.330040648629748 242.31084409917329 L 122.6600812972595 225.81065877321842 L 185.32016259451899 186.90442448827019 L 310.64032518903798 139.48353217036845" style="fill:none;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0;stroke-width:2.0"></path><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0"><circle cx="61.958127540539365" cy="258.4375" r="3.1622776601683795"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0"><circle cx="63.916255081078717" cy="257.44366040051301" r="3.1622776601683795"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0"><circle cx="67.832510162157433" cy="255.0587380091398" r="3.1622776601683795"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0"><circle cx="75.665020324314867" cy="248.49733255508005" r="3.1622776601683795"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0"><circle cx="91.330040648629748" cy="242.31084409917329" r="3.1622776601683795"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0"><circle cx="122.6600812972595" cy="225.81065877321842" r="3.1622776601683795"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0"><circle cx="185.32016259451899" cy="186.90442448827019" r="3.1622776601683795"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0"><circle cx="310.64032518903798" cy="139.48353217036845" r="3.1622776601683795"></circle></g></g><g class="toyplot-Series"><path d="M 60.489531885134838 259.69208466556358 L 60.979063770269683 259.43625623973247 L 61.958127540539365 258.97599052724706 L 63.916255081078717 258.03604824896115 L 67.832510162157433 256.12972249447631 L 75.665020324314867 253.5183974320216 L 91.330040648629748 251.02373184965515 L 122.6600812972595 249.59952316518661 L 185.32016259451899 244.19149098321253" style="fill:none;stroke:rgb(98.8%,55.3%,38.4%);stroke-opacity:1.0;stroke-width:2.0"></path><g class="toyplot-Datum" style="fill:rgb(98.8%,55.3%,38.4%);fill-opacity:1.0;opacity:1.0;stroke:rgb(98.8%,55.3%,38.4%);stroke-opacity:1.0"><circle cx="60.489531885134838" cy="259.69208466556358" r="3.1622776601683795"></circle></g><g class="toyplot-Datum" style="fill:rgb(98.8%,55.3%, ...

# %% [markdown]
# Save the plot as [HabibRate.pdf](HabibRate.pdf).

# %%
toyplot.pdf.render(canvas, 'HabibRate.pdf')

# %% [markdown]
# ## Efficiency Plot

# %%
efficiency_series = data.pivot_table(index='Number of Nodes',
                                     columns='Study',
                                     values='efficiency')
efficiency_series
# Out:
# Study              Strong      Weak
# Number of Nodes
# 32               0.788263       NaN
# 64               0.721592       NaN
# 128              0.655366  1.000000
# 256              0.628465  0.818029
# 512              0.619244  0.790602
# 1024             0.518528  0.920213
# 2048             0.359051  0.707566
# 4096             0.208010  0.683787
# 8192             0.158085  0.730956
# 16384                 NaN  0.602582

# %%
canvas = toyplot.Canvas(400, 320)
axes = canvas.axes(xscale='linear',
                   yscale='linear',
                   xlabel='Number of Nodes',
                   ylabel='Efficiency')
axes.x.ticks.locator = toyplot.locator.Explicit(numpy.arange(0,2**14+2**12,2**12))
axes.x.ticks.show = True
axes.y.ticks.show = True
axes.x.domain.min = 0

x = efficiency_series.index.values
y = numpy.column_stack((efficiency_series['Weak'], efficiency_series['Strong']))
axes.plot(x, y, marker='o', size=40)
axes.text(16384, efficiency_series['Weak'][16384], 'Weak Scaling',
          style={'text-anchor':'end', 'baseline-shift':'80%'},
          angle=-12.5)
axes.text(8192+300, efficiency_series['Strong'][8192], 'Strong Scaling',
          style={'text-anchor':'start'})
# Out:
# <div align="center" class="toyplot" id="tfcec90c598d84635a20771800209427c"><svg height="320.0px" id="t3bb6c69f3c8c428785f20b852c7adfdc" preserveAspectRatio="xMidyMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 400.0 320.0" width="400.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-axes-Cartesian" id="teff127d8c9784bc084bfba5b34380880"><clipPath id="t3b713f30c251445fa2030523f6cccb54"><rect height="220.0" width="300.0" x="50.0" y="50.0"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#t3b713f30c251445fa2030523f6cccb54)" style="cursor:crosshair"><rect height="220.0" style="pointer-events:all;visibility:hidden" width="300.0" x="50.0" y="50.0"></rect><g class="toyplot-mark-Plot" id="t2e5cf54bb8be435f87fcc535ab2b49b3" style="fill:none"><g class="toyplot-Series"><path d="M 61.958127540539365 60.0 L 63.916255081078717 96.394265632833196 L 67.832510162157433 101.87961629247431 L 75.665020324314867 75.957320881280594 L 91.330040648629748 118.48675279338622 L 122.6600812972595 123.24263509287371 L 185.32016259451899 113.80884897654039 L 310.64032518903798 139.48353217036845" style="fill:none;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0;stroke-width:2.0"></path><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0"><circle cx="61.958127540539365" cy="60.0" r="3.1622776601683795"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0"><circle cx="63.916255081078717" cy="96.394265632833196" r="3.1622776601683795"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0"><circle cx="67.832510162157433" cy="101.87961629247431" r="3.1622776601683795"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0"><circle cx="75.665020324314867" cy="75.957320881280594" r="3.1622776601683795"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0"><circle cx="91.330040648629748" cy="118.48675279338622" r="3.1622776601683795"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0"><circle cx="122.6600812972595" cy="123.24263509287371" r="3.1622776601683795"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0"><circle cx="185.32016259451899" cy="113.80884897654039" r="3.1622776601683795"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0"><circle cx="310.64032518903798" cy="139.48353217036845" r="3.1622776601683795"></circle></g></g><g class="toyplot-Series"><path d="M 60.489531885134838 102.34734876856687 L 60.979063770269683 115.68159737151512 L 61.958127540539365 128.92678748762222 L 63.916255081078717 134.30708793351258 L 67.832510162157433 136.15111982324294 L 75.665020324314867 156.29435891234596 L 91.330040648629748 188.18985479724114 L 122.6600812972595 218.39809266074653 L 185.32016259451899 228.38298196642506" style="fill:none;stroke:rgb(98.8%,55.3%,38.4%);stroke-opacity:1.0;stroke-width:2.0"></path><g class="toyplot-Datum" style="fill:rgb(98.8%,55.3%,38.4%);fill-opacity:1.0;opacity:1.0;stroke:rgb(98.8%,55.3%,38.4%);stroke-opacity:1.0"><circle cx="60.489531885134838" cy="102.34734876856687" r="3.1622776601683795"></circle></g><g class="toyplot-Datum" style="fill:rgb(98.8%,55.3%,38.4% ...

# %% [markdown]
# Save the plot as [HabibEfficiency.pdf](HabibEfficiency.pdf).

# %%
toyplot.pdf.render(canvas, 'HabibEfficiency.pdf')
